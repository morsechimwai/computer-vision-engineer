# %% [markdown]
# ### Install Libraries
# - OpenCV (opencv-python)
# - Pillow (pillow)
# - Matplotlib (matplotlib)

# %% [markdown]
# ### Read Image

# %% [markdown]
# #### OpenCV
# - read image to array, default colors = BGR

# %%
import cv2
import matplotlib.pyplot as plt

# read image
img = cv2.imread("images/lenna.png")

assert img is not None, "Cannot read image"

# convert BGR → RGB to display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis("off")
plt.show()
# Out:
# [ WARN:0@42.602] global loadsave.cpp:275 findDecoder imread_('images/lenna.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 7
#       4 # read image
#       5 img = cv2.imread("images/lenna.png")
# ----> 7 assert img is not None, "Cannot read image"
#       9 # convert BGR → RGB to display
#      10 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#
# AssertionError: Cannot read image

# %% [markdown]
# #### Pillow
# - read image using pillow

# %%
from PIL import Image

img_pil = Image.open("images/lenna.png")
img_pil.show()

# %% [markdown]
# ### Image Resizing

# %% [markdown]
# #### OpenCV

# %%
resized = cv2.resize(img_rgb, (200, 200))  # กำหนดขนาดใหม่
plt.imshow(resized)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Pillow

# %%
resized_pil = img_pil.resize((200, 200))
resized_pil.show()

# %% [markdown]
# ### Filtering (Blur/Sharpen/Edge Detection)

# %% [markdown]
# #### OpenCV

# %%
# Gaussian Blur
blur = cv2.GaussianBlur(img_rgb, (5,5), 0)

plt.subplot(1,2,1)
plt.title("Blur")
plt.imshow(blur)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %%
# Edge Detection (Canny)
edges = cv2.Canny(img_rgb, 100, 200)

plt.subplot(1,2,2)
plt.title("Edges")
plt.imshow(edges, cmap="gray")
plt.axis("off")
plt.show()

# %% [markdown]
# #### Pillow
# - using ImageFilter

# %%
from PIL import ImageFilter

blur_pil = img_pil.filter(ImageFilter.GaussianBlur(5))
sharpen_pil = img_pil.filter(ImageFilter.SHARPEN)

blur_pil.show()
sharpen_pil.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from PIL import ImageFilter
# ----> 3 blur_pil = img_pil.filter(ImageFilter.GaussianBlur(5))
#       4 sharpen_pil = img_pil.filter(ImageFilter.SHARPEN)
#       6 blur_pil.show()
#
# NameError: name 'img_pil' is not defined
